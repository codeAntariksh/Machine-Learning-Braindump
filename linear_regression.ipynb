# %% [markdown]
# ### Linear Regression

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# Using Scikit Learn

# %%
df = pd.read_csv(r"placement.csv")
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel("CGPA")
plt.ylabel("Package")
plt.show()

# %%
X = df.iloc[:,0:1]
Y = df.iloc[:,1:2]
Y
# Out:
#      package
# 0       3.26
# 1       1.98
# 2       3.25
# 3       3.67
# 4       3.57
# ..       ...
# 195     2.46
# 196     2.57
# 197     3.24
# 198     3.96
# 199     2.33
#
# [200 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression
lr  = LinearRegression()
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#      cgpa
# 112  8.58
# 29   7.15
# 182  5.88
# 199  6.22
# 193  4.57
# 85   4.79
# 10   5.32
# 54   6.86
# 115  8.35
# 35   6.87
# 12   8.94
# 92   7.90
# 13   6.93
# 126  5.91
# 174  7.32
# 2    7.82
# 44   5.09
# 3    7.42
# 113  6.94
# 14   7.73
# 23   6.19
# 25   7.28
# 6    6.73
# 134  7.20
# 165  8.21
# 173  6.75
# 45   7.87
# 65   7.60
# 48   8.63
# 122  5.12
# 178  8.15
# 64   7.36
# 9    8.31
# 57   6.60
# 78   6.59
# 71   7.47
# 128  7.93
# 176  6.29
# 131  6.37
# 53   6.47

# %%
Y_test
# Out:
#      package
# 112     4.10
# 29      3.49
# 182     2.08
# 199     2.33
# 193     1.94
# 85      1.48
# 10      1.86
# 54      3.09
# 115     4.21
# 35      2.87
# 12      3.65
# 92      4.00
# 13      2.89
# 126     2.60
# 174     2.99
# 2       3.25
# 44      1.86
# 3       3.67
# 113     2.37
# 14      3.42
# 23      2.48
# 25      3.65
# 6       2.60
# 134     2.83
# 165     4.08
# 173     2.56
# 45      3.58
# 65      3.81
# 48      4.09
# 122     2.01
# 178     3.63
# 64      2.92
# 9       3.51
# 57      1.94
# 78      2.21
# 71      3.34
# 128     3.34
# 176     3.23
# 131     2.01
# 53      2.61

# %%
lr.predict(X_test.iloc[2].values.reshape(1,1))
# Out:
# c:\Users\ANTARIKSHYA\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[2.38464568]])

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_train,lr.predict(X_train),color="red")
plt.xlabel("CGPA")
plt.ylabel("Package")
plt.show()

# %%
m = lr.coef_ # SLope
m
# Out:
# array([[0.55795197]])

# %%
b = lr.intercept_# Intercept
b
# Out:
# array([-0.89611192])

# %%
# y = m*x + b
m * 9.5 + b
# Out:
# array([[4.40443183]])

# %% [markdown]
# ### Coding from Scratch

# %%
class LR:
    def __init__(self):
        self.m=0
        self.b=0
    def fit(self,X_train,y_train):
        num = 0
        den = 0
        for i in range(X_train.shape[0]):
            num += ((X_train[i] - X_train.mean()) * (y_train[i] - y_train.mean()))
            den += (X_train[i] - X_train.mean()) * ((X_train[i] - X_train.mean()))

        self.m = num/den
        self.b = y_train.mean() - (self.m * X_train.mean())
    def predict(self,x_test):
        print(self.m*x_test+self.b)
        return self.m*x_test+self.b

# %%
df = pd.read_csv(r"placement.csv")
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
X = df.iloc[:,0:1].values
y = df.iloc[:,-1].values
import sklearn

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
X_train.shape
# Out:
# (160, 1)

# %%
lr = LR()

# %%
lr.fit(X_train,y_train)

# %%
# class LR:
#     def __init__(self):
#         self.m=0
#         self.b=0
#     def fit(self,x_train,y_train):
#         print(x_train.shape)
#     def predict(self,x_test):
#         pass

# import pandas as pd
# from sklearn.model_selection import train_test_split

# df = pd.read_csv("placement.csv")
# X = df.iloc[:,0:1].values
# y = df.iloc[:,-1].values
# X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# lr = LR()
# lr.fit(X_train,y_train)

# %%
# class LR:
#     def __init__(self):
#         self.m=0
#         self.b=0
#     def fit(self,X_train,y_train):
#         num = 0
#         den = 0
#         for i in range(X_train.shape[0]):
#             num += ((X_train[i] - X_train.mean()) * (y_train[i] - y_train.mean()))
#             den += (X_train[i] - X_train.mean()) * ((X_train[i] - X_train.mean()))

#         self.m = num/den
#         self.b = y_train.mean() - (self.m * X_train.mean())
#         print(self.m,self.b)
#     def predict(self,x_test):
#         pass


# lr = LR()
# lr.fit(X_train,y_train)
# Out:
# [0.55795197] [-0.89611192]

# %%
lr = LR()
lr.fit(X_train,y_train)
print(lr.predict(X_test[0]))
# Out:
# [3.89111601]

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
lr.predict(X_test)
# Out:
# array([[3.89111601],
#        [3.09324469],
#        [2.38464568],
#        [2.57434935],
#        [1.6537286 ],
#        [1.77647803],
#        [2.07219258],
#        [2.93143862],
#        [3.76278706],
#        [2.93701814],
#        [4.09197872],
#        [3.51170867],
#        [2.97049525],
#        [2.40138424],
#        [3.18809652],
#        [3.46707251],
#        [1.94386362],
#        [3.24389172],
#        [2.97607477],
#        [3.41685683],
#        [2.55761079],
#        [3.16577844],
#        [2.85890486],
#        [3.12114229],
#        [3.68467378],
#        [2.8700639 ],
#        [3.49497011],
#        [3.34432308],
#        [3.91901361],
#        [1.96060218],
#        [3.65119666],
#        [3.2104146 ],
#        [3.74046898],
#        [2.7863711 ],
#        [2.78079158],
#        [3.27178932],
#        [3.52844723],
#        [2.61340599],
#        [2.65804215],
#        [2.71383735]])

# %%
y_pred = lr.predict(X_test)

# %%
y_pred
# Out:
# array([[3.89111601],
#        [3.09324469],
#        [2.38464568],
#        [2.57434935],
#        [1.6537286 ],
#        [1.77647803],
#        [2.07219258],
#        [2.93143862],
#        [3.76278706],
#        [2.93701814],
#        [4.09197872],
#        [3.51170867],
#        [2.97049525],
#        [2.40138424],
#        [3.18809652],
#        [3.46707251],
#        [1.94386362],
#        [3.24389172],
#        [2.97607477],
#        [3.41685683],
#        [2.55761079],
#        [3.16577844],
#        [2.85890486],
#        [3.12114229],
#        [3.68467378],
#        [2.8700639 ],
#        [3.49497011],
#        [3.34432308],
#        [3.91901361],
#        [1.96060218],
#        [3.65119666],
#        [3.2104146 ],
#        [3.74046898],
#        [2.7863711 ],
#        [2.78079158],
#        [3.27178932],
#        [3.52844723],
#        [2.61340599],
#        [2.65804215],
#        [2.71383735]])

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
# Out:
# MAE 0.2884710931878174

# %%
print("MSE",mean_squared_error(y_test,y_pred))
# Out:
# MSE 0.12129235313495523

# %%
print("RMSE",mean_squared_error(y_test,y_pred)**0.5)
# Out:
# RMSE 0.3482705171773161

# %%
print("R2 Score",r2_score(y_test,y_pred)*100,"%")
# Out:
# R2 Score 78.07301475103841 %

# %%
# Adjusted R2 Score 
r2 = r2_score(y_test,y_pred)
n = X_test.shape[0]
r2adj = 1 - ((1-r2)*(n-1)/(n-1-1))
print("R2 Adj",r2adj*100,"%")
# Out:
# R2 Adj 77.49598882343417 %

# %%
new_df1 = df.copy()
new_df1['random feature'] = np.random.random(200)

new_df1 = new_df1[['cgpa','random feature','package']]
new_df1.head()
# Out:
#    cgpa  random feature  package
# 0  6.89        0.626359     3.26
# 1  5.12        0.123128     1.98
# 2  7.82        0.269745     3.25
# 3  7.42        0.302423     3.67
# 4  6.94        0.764481     3.57

# %%
X = new_df1.iloc[:,0:2]
y = new_df1.iloc[:,-1]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
print("R2 Score",r2_score(y_test,y_pred)*100,"%")
r2 = r2_score(y_test,y_pred)
n = X_test.shape[0]
r2adj = 1 - ((1-r2)*(n-1)/(n-2-1))
print("R2 Adj",r2adj*100,"%")
# Out:
# R2 Score 76.9629642373221 %
# R2 Adj 75.71771906096113 %

# %%
new_df2 = df.copy()
new_df2['iq'] = new_df2['package'] + (np.random.randint(-12,12,200)/10)
new_df2 = new_df2[['cgpa','iq','package']]
new_df2.sample(5)
# Out:
#      cgpa    iq  package
# 156  7.38  3.63     3.13
# 81   6.10  2.40     2.20
# 119  7.39  1.55     2.65
# 197  7.21  2.54     3.24
# 129  7.29  4.02     3.12

# %%
plt.scatter(new_df2['iq'],new_df2['package'])
plt.xlabel('iq')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
X = new_df2.iloc[:,0:2]
y = new_df2.iloc[:,-1]
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=2,test_size=0.2)
lr = LinearRegression()
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)
print("R2 score =",r2_score(y_test,y_pred)*100,"%")
r2 = r2_score(y_test,y_pred)
r2_adj = 1 - ((1-r2)*(40-1)/(40-1-2))
print("R2 Adj =",r2_adj*100,"%")
# Out:
# R2 score = 81.76140375211563 %
# R2 Adj = 80.77553368466242 %

# %% [markdown]
# Multiple Linear Regression
